# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
data = np.genfromtxt('my_equ0.txt', skip_header=1)
it = data[:,0]
Nt = data[:,1]
Et = data[:,2]
_ = ax.set_xlabel('Step')
_ = ax.set_ylabel(r'$E_0$')
_ = ax.plot(it, Et, alpha=0.75)
_ = ax.axhline(y=np.mean(Et[1000:]), color='red', label=r'$E_0 = %6.5f$' % np.mean(Et[1000:]))
_ = ax.legend()
#fig.savefig('converged_128atm_1000walks.pdf')
