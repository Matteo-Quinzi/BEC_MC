# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt('DMC.out', skip_header=1)
r = data[:,0]
rho = data[:,1]

fig, ax = plt.subplots()
ax.plot(r,rho)

# %%
print(np.sum(rho))
# Out:
# 10.0961205694
